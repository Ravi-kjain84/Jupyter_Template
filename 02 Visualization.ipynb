# %%
import pandas            as     pd
import seaborn           as     sns
import matplotlib.pyplot as     plt
from sklearn             import datasets
from seaborn             import get_dataset_names
import  pandas_profiling
# %matplotlib inline

#datasets.load*?
#get_dataset_names()

# %%
def sklearn_to_df(sklearn_dataset):
    df            = pd.DataFrame(sklearn_dataset.data, columns=sklearn_dataset.feature_names)
    df['target']  = pd.Series(sklearn_dataset.target)
    return df

# %%
tips = sns.load_dataset('tips')
df = sns.load_dataset('tips')

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical_columns = df.select_dtypes(include=numerics)
categorical_columns = df.select_dtypes(exclude=numerics)

# %%
#df = sklearn_to_df(datasets.load_iris())

# %%
# profile = df.profile_report(title='Pandas Profiling Report',html={'style':{'full_width':True}})
# profile.to_file(output_file="output/Pandas Profiling Report.html")
# profile

# %%
#sns.set_style("ticks")
sns.pairplot(df)
plt.show()

# %%
current_palette1 = sns.color_palette()
sns.palplot(current_palette1)

current_palette2 = sns.color_palette("Greens")
sns.palplot(current_palette2)

current_palette3 = sns.color_palette("BrBG", 7)
sns.palplot(current_palette3)

# %%
#sns.set_style("dark")
#sns.set_palette("husl")

# %% [markdown]
# Univariate - Numerical

# %%
for num_col in numerical_columns:
    #col = 'total_bill'
    print(num_col)
    fig, axs = plt.subplots(ncols = 5, figsize = (20,4))
    sns.distplot(tips[num_col],               ax = axs[0]) 
    sns.swarmplot(tips[num_col],              ax = axs[1]) 
    #sns.countplot(tips[col],              ax = axs[2]) 
    sns.boxplot(x=tips[num_col],              ax = axs[3])
    sns.violinplot(x=tips[num_col],           ax = axs[4])
    plt.tight_layout()
    plt.show()
# Out:
# total_bill
# tip
# size

# %% [markdown]
# Univariate - Categorical

# %%
for cat_col in categorical_columns:
    print(cat_col)
    #col = 'smoker'
    fig, axs = plt.subplots(ncols = 5, figsize = (20,4))
    #sns.distplot(tips[col],               ax = axs[0]) 
    #sns.swarmplot(tips[col],              ax = axs[1]) 
    sns.countplot(tips[cat_col],              ax = axs[2]) 
    #sns.boxplot(x=tips[col],              ax = axs[3])
    #sns.violinplot(x=tips[col],           ax = axs[4])
    plt.tight_layout()
    plt.show()
# Out:
# sex
# smoker
# day
# time

# %% [markdown]
# Bivariate - (numerical-numerical)

# %%
sns.jointplot(x="total_bill", y="tip", data=tips)
sns.scatterplot(x="total_bill", y="tip", data=tips)
sns.regplot(x="total_bill", y="tip", data=tips)
sns.lmplot(x="total_bill", y="tip", data=tips)
ns.residplot(x="total_bill", y="tip", data=tips)
sns.pairplot(tips)

# %%
g = sns.PairGrid(tips)
g = g.map(plt.scatter)

# %%
g = sns.PairGrid(tips)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sns.regplot, sns.distplot)

# %% [markdown]
# Bivariate - (numerical-categorical)

# %%
sns.stripplot(x="day", y="total_bill", data=tips)
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
sns.swarmplot(x="day", y="total_bill", data=tips)
sns.boxplot(x="day", y="total_bill", data=tips)
sns.violinplot(x="day", y="total_bill", data=tips)
sns.barplot(x="day", y="total_bill", data=tips)
sns.pointplot(x="time", y="total_bill", data=tips)

# %% [markdown]
# Bivariate - (categorical - categorical)

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill")

# %% [markdown]
# Multi-variate

# %%
sns.pointplot(x="time", y="total_bill", hue="smoker", data=tips)
