# %% [markdown]
# # Dataset Name<a name=Top></a>

# %% [markdown]
# 1. [Introduction](#introduction)<br>
#     1.1 [Background](#background)<br>
#     1.2 [Data Description](#datadescription)<br>
#     1.3 [Problem Statement](#problemstatement)<br>
# 2. [Data Exploration](#dataexploration)<br>
#     2.1 [Data Load](#dataload)<br>
#     2.2 [Data Analysis](#data_analysis)<br>
#     2.3 [Exploratory Data Analysis(before data cleaning)](#eda1)<br>
#     2.4 [Data Cleaning](#null)<br>
#     2.5 [Normality Test](#normality)<br>
#     2.6 [Exploratory Data Analysis(after data cleaning)](#eda2)<br>

# %% [markdown]
# # 1. Introduction<a introduction></a>

# %% [markdown]
# ## 1.1 Background<a background></a>

# %% [markdown]
# [Top](#Top)</br>

# %% [markdown]
# A commercial success movie not only entertains audience, but also enables film companies to gain tremendous profit. A lot of factors such as good directors, experienced actors are considerable for creating good movies. However, famous directors and actors can always bring an expected box-office income but cannot guarantee a highly rated imdb score.

# %% [markdown]
# <a id='datadescription'></a>

# %% [markdown]
# ## 1.2 Data Description<a datadescription></a>

# %% [markdown]
# [Top](#Top)</br>

# %% [markdown]
# The dataset is from Kaggle website. It contains 28 variables for 5043 movies, spanning across 100 years in 66 countries. There are 2399 unique director names, and thousands of actors/actresses. “imdb_score” is the response variable while the other 27 variables are possible predictors.

# %% [markdown]
# |Variable Name |	Description|
# | --- | --- |
# |movie_title	 | Title of the Movie|
# |duration	| Duration in minutes|
# |director_name	| Name of the Director of the Movie|
# |director_facebook_likes |	Number of likes of the Director on his Facebook Page|
# |actor_1_name |	Primary actor starring in the movie|
# |actor_1_facebook_likes |	Number of likes of the Actor_1 on his/her Facebook Page|
# |actor_2_name |	Other actor starring in the movie|
# |actor_2_facebook_likes	| Number of likes of the Actor_2 on his/her Facebook Page|
# |actor_3_name |	Other actor starring in the movie|
# |actor_3_facebook_likes |	Number of likes of the Actor_3 on his/her Facebook Page|
# |num_user_for_reviews |	Number of users who gave a review|
# |num_critic_for_reviews |	Number of critical reviews on imdb|
# |num_voted_users | 	Number of people who voted for the movie|
# |cast_total_facebook_likes |	Total number of facebook likes of the entire cast of the movie|
# |movie_facebook_likes |	Number of Facebook likes in the movie page|
# |plot_keywords |	Keywords describing the movie plot|
# |facenumber_in_poster |	Number of the actor who featured in the movie poster|
# |color |	Film colorization. ‘Black and White’ or ‘Color’|
# |genres |	Film categorization like ‘Animation’, ‘Comedy’, ‘Romance’, ‘Horror’, ‘Sci-Fi’, ‘Action’, ‘Family’|
# |title_year |	The year in which the movie is released (1916:2016)|
# |language |	English, Arabic, Chinese, French, German, Danish, Italian, Japanese etc|
# |country |	Country where the movie is produced|
# |content_rating |	Content rating of the movie|
# |aspect_ratio |	Aspect ratio the movie was made in|
# |movie_imdb_link |	IMDB link of the movie|
# |gross |	Gross earnings of the movie in Dollars|
# |budget |	Budget of the movie in Dollars|
# |imdb_score |	IMDB Score of the movie on IMDB|

# %% [markdown]
# <a id='problemstatement'></a>

# %% [markdown]
# ## 1.3 Problem Statement<a problemstatement></a>

# %% [markdown]
# [Top](#Top)</br>

# %% [markdown]
# Based on the massive movie information, it would be interesting to understand what are the important factors that make a movie more successful than others. So, we would like to analyze what kind of movies are more successful, in other words, get higher IMDB score.
#
# In this notebook we are going to build two different kind of models, Regression and Classification. Under each kind of model we are going to start from a basic model to advanced model and also a description of why we choose advanced one.
#
# Under Regression we are goint to fit Regression line to our data and find the continous target variable imdb_score.
#
# Under Classification we are  going to fit the Classification Model to our data and the Classify the imdb_score in to three categories.

# %% [markdown]
# |imdb_score | Classify |
# | --- | ---|
# |1-3 | Flop Movie|
# |3-6 | Average Movie|
# |6-10 | Hit Movie|

# %% [markdown]
# # 2 Data Exploration<a name=dataexploration></a>

# %% [markdown]
# ## 2.1 Data Load<a name=dataload></a>

# %% [markdown]
# [Top](#Top)</br>

# %%
import pandas as pd
import numpy as np
import mysql.connector as sql
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pp
import warnings

# %matplotlib inline
warnings.filterwarnings('ignore')
sns.set(color_codes=True)
pd.set_option('display.max_rows', 20)

# %%
db = sql.connect(host = 'localhost',database='dataset',user='root',password='root')
cursor = db.cursor(buffered = True)
cursor.execute('show tables')
print(cursor.fetchall())
# Out:
# [('anscombe',), ('auto',), ('car_crashes',), ('cardio',), ('imdb',)]

# %%
Input = pd.read_sql('select * from imdb',con=db)

# %%
print(sns.get_dataset_names())
Input = sns.load_dataset('dots')
# Out:
# ['anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'iris', 'mpg', 'planets', 'tips', 'titanic']

# %% [markdown]
# ## 2.2 Data Analysis<a name=data_analysis></a>

# %% [markdown]
# [Top](#Top)</br>

# %%
df = Input.copy()

# %%
df.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 848 entries, 0 to 847
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   align        848 non-null    object
#  1   choice       848 non-null    object
#  2   time         848 non-null    int64
#  3   coherence    848 non-null    float64
#  4   firing_rate  848 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 33.2+ KB

# %%
df.dtypes
# Out:
# align           object
# choice          object
# time             int64
# coherence      float64
# firing_rate    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['align', 'choice', 'time', 'coherence', 'firing_rate'], dtype='object')

# %%
df.describe(include = 'all').round(2)
# Out:
#        align choice    time  coherence  firing_rate
# count    848    848  848.00     848.00       848.00
# unique     2      2     NaN        NaN          NaN
# top     sacc     T2     NaN        NaN          NaN
# freq     454    430     NaN        NaN          NaN
# mean     NaN    NaN   74.15      12.90        39.62
# std      NaN    NaN  284.60      15.45        12.23
# min      NaN    NaN -600.00       0.00         6.28
# 25%      NaN    NaN -100.00       3.20        32.62
# 50%      NaN    NaN   80.00       6.40        38.02
# 75%      NaN    NaN  260.00      12.80        47.38
# max      NaN    NaN  720.00      51.20        70.05

# %%
df.isnull().sum()
# Out:
# align          0
# choice         0
# time           0
# coherence      0
# firing_rate    0
# dtype: int64

# %%
df.dtypes
# Out:
# align           object
# choice          object
# time             int64
# coherence      float64
# firing_rate    float64
# dtype: object

# %%
cat_cols = df.select_dtypes(exclude=['float64','int64'])
num_cols = df.select_dtypes(include=['float64','int64'])

# %%
df.profile_report()
# Out:
# ...
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.5.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ## 2.3 Exploratory Data Analysis (before data cleaning)<a name=eda1></a>

# %%
df.dtypes
# Out:
# align           object
# choice          object
# time             int64
# coherence      float64
# firing_rate    float64
# dtype: object

# %%
df.hist(figsize=(10,10));
#mydata.hist(by='Gender',column = 'Age');

# %%
sns.pairplot(df);

# %%
print('Category Columns :',cat_cols.columns,'\n','Numerical Columns :',num_cols.columns)
# Out:
# Category Columns : Index(['align', 'choice'], dtype='object')
#  Numerical Columns : Index(['time', 'coherence', 'firing_rate'], dtype='object')

# %%
for col in cat_cols:
    print(col,df[col].unique(),'\n')
# Out:
# align ['dots' 'sacc']
#
# choice ['T1' 'T2']

# %%
#sns.boxplot(x='time',y = 'align',data=df);

# %%
#kind of plot: 'line','bar','barh','hist','box','kde','density','area','pie','scatter','hexbin'
# print(pd.crosstab(df['align'],df['choice'] ))
# pd.crosstab(df['align'],df['choice'] ).plot(kind='line',figsize=None);

# %%
#sns.countplot(x="Product", hue="Gender", data=mydata)

# %%
#sns.distplot(mydata['Age']);

# %%
# corr = mydata.corr()
# corr

# %%
#sns.heatmap(corr, annot=True);

# %%
#kind of plot: 'line','bar','barh','hist','box','kde','density','area','pie','scatter','hexbin'
# pd.pivot_table(mydata,'Miles',index=['Product','Gender'],
#               columns=['MaritalStatus']).plot()

# %%
#kind of plot: 'line','bar','barh','hist','box','kde','density','area','pie','scatter','hexbin'
#mydata.groupby(['Product'])['Age'].mean().plot()

# %% [markdown]
# ## 2.4 Data Cleaning<a name=datacleaning></a>

# %% [markdown]
# ### 2.4.1 Remove duplicates<a name=removeduplicates></a>

# %% [markdown]
# [Top](#Top)</br>

# %%
duplicateRowsDF = df[df.duplicated()]
 
# print("Duplicate Rows except first occurrence based on all columns are :")
# print(duplicateRowsDF)

# %%
#dataset.reset_index(inplace = True, drop = True)

# %%
df.shape
# Out:
# (848, 5)

# %%
df.drop_duplicates(inplace = True)
df.shape
# Out:
# (848, 5)

# %% [markdown]
# ### 2.4.2 Handle null values<a name=null></a>

# %% [markdown]
# [Top](#Top)</br>

# %%
df.isnull().sum()
# Out:
# align          0
# choice         0
# time           0
# coherence      0
# firing_rate    0
# dtype: int64

# %%
# aspect_ratio_mode = dataset.aspect_ratio.mode().iloc[0]
# dataset.aspect_ratio.fillna(aspect_ratio_mode, inplace = True)

# %% [markdown]
# ### 2.4.3 Others data cleaning<a name=others></a>

# %% [markdown]
# [Top](#Top)</br>

# %% [markdown]
# ## 2.5 Normality Test <a name=normality></a>

# %% [markdown]
# [Top](#Top)</br>

# %%
# %%time
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from numpy import std
# Out:
# CPU times: user 10 µs, sys: 1e+03 ns, total: 11 µs
# Wall time: 14.1 µs

# %%
seed(1)
data = 5* randn(100) + 50

# %%
df.columns
# Out:
# Index(['align', 'choice', 'time', 'coherence', 'firing_rate'], dtype='object')

# %%
#data =df['firing_rate']
#dlog = data.apply(lambda x: np.log(x))

# %%
print('mean = %.3f std = %.3f' %(mean(data),std(data)))
# Out:
# mean = 50.303 std = 4.426

# %%
plt.hist(data)
plt.show()

# %%
sns.distplot(data)
plt.show()

# %%
from statsmodels.graphics.gofplots import qqplot
# q-q plot
qqplot(data, line='s')
plt.show()

# %% [markdown]
# ##### Shapiro-Wilk Test

# %%
from scipy.stats import shapiro

# normality test
stat, p = shapiro(data)
print('Statistics=%.5f, p=%.5f' % (stat, p))

# interpret
alpha = 0.05
if p > alpha:
	print('Sample looks Gaussian (fail to reject H0)')
else:
	print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.99200, p=0.82154
# Sample looks Gaussian (fail to reject H0)

# %% [markdown]
# ##### D’Agostino’s K^2 Test

# %%
from scipy.stats import normaltest
# normality test
stat, p = normaltest(data)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('Sample looks Gaussian (fail to reject H0)')
else:
	print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.102, p=0.950
# Sample looks Gaussian (fail to reject H0)

# %% [markdown]
# ##### Anderson-Darling Test

# %%
from scipy.stats import anderson

# %%
# normality test
result = anderson(data)
print('Statistic: %.3f' % result.statistic)
p = 0
for i in range(len(result.critical_values)):
	sl, cv = result.significance_level[i], result.critical_values[i]
	if result.statistic < result.critical_values[i]:
		print('%.3f: %.3f, data looks normal (fail to reject H0)' % (sl, cv))
	else:
		print('%.3f: %.3f, data does not look normal (reject H0)' % (sl, cv))
# Out:
# Statistic: 7.782
# 15.000: 0.573, data does not look normal (reject H0)
# 10.000: 0.653, data does not look normal (reject H0)
# 5.000: 0.783, data does not look normal (reject H0)
# 2.500: 0.914, data does not look normal (reject H0)
# 1.000: 1.087, data does not look normal (reject H0)

# %%
data = data.apply(lambda x: np.log(x))

# %% [markdown]
# ## 2.6 Exploratory Data Analysis (after data cleaning)<a name=eda2></a>

# %% [markdown]
# [Top](#Top)</br>

# %% [markdown]
# Changes
